# %% [markdown]
# <a href="https://colab.research.google.com/github/jessycalais/API_BigQuery_Python/blob/main/sql_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Objetivo:**
# * Utilizar o método `.shift()` da biblioteca Pandas para realizar análise semelhante a obtida com a função de janela LAG() no SQL.

# %% [markdown]
# 1. Conexão com a API do **BigQuery**

# %%
from google.colab import auth
from google.cloud import bigquery

auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# 2. A tabela utilizada neste projeto está disponível no seguinte conjunto de dados públicos do **Big Query**:
#
# > `bigquery-public-data.covid19_ecdc.covid_19_geographic_distribution_worldwide`
#
# Antes de prosseguir, vamos realizar a conexão com um projeto privado no meu perfil de usuário:

# %%
client = bigquery.Client(project='formal-chassis-396823')

# %% [markdown]
# 3.1. Consulta utilizando a instrução CASE e a função de janela LAG():

# %%
consulta_avancada_sql = client.query('''
                            SELECT
                              countries_and_territories,
                              CASE month
                                WHEN 1 THEN 'jan'
                                WHEN 2 THEN 'fev'
                                WHEN 3 THEN 'mar'
                                WHEN 4 THEN 'abr'
                                WHEN 5 THEN 'mai'
                                WHEN 6 THEN 'jun'
                                WHEN 7 THEN 'jul'
                                WHEN 8 THEN 'ago'
                                WHEN 9 THEN 'set'
                                WHEN 10 THEN 'out'
                                WHEN 11 THEN 'nov'
                                WHEN 12 THEN 'dez'
                              END AS mes,
                              SUM(daily_confirmed_cases) AS total_confirmed_cases,
                              LAG(SUM(daily_confirmed_cases))
                                OVER(PARTITION BY countries_and_territories ORDER BY month)
                                AS total_cases_previous_month,
                              ROUND((SAFE_DIVIDE(SUM(daily_confirmed_cases),
                                  (LAG(SUM(daily_confirmed_cases))
                                  OVER(PARTITION BY countries_and_territories ORDER BY month))) - 1) * 100, 2)
                                AS percentage_increase
                            FROM
                              `bigquery-public-data.covid19_ecdc.covid_19_geographic_distribution_worldwide`
                            WHERE
                              year = 2020
                              AND countries_and_territories = 'Brazil'
                            GROUP BY
                              month,
                              countries_and_territories
                            ORDER BY
                              countries_and_territories,
                              month,
                              total_confirmed_cases
                        ''').to_dataframe()

# %%
consulta_avancada_sql
# Out:
#    countries_and_territories  mes  total_confirmed_cases  \
# 0                     Brazil  jan                      0
# 1                     Brazil  fev                      1
# 2                     Brazil  mar                   4578
# 3                     Brazil  abr                  73583
# 4                     Brazil  mai                 420278
# 5                     Brazil  jun                 869755
# 6                     Brazil  jul                1241907
# 7                     Brazil  ago                1252209
# 8                     Brazil  set                 915211
# 9                     Brazil  out                 739136
# 10                    Brazil  nov                 798082
# 11                    Brazil  dez                 587212
#
#     total_cases_previous_month  percentage_increase
# 0                         <NA>                  NaN
# 1                            0                  NaN
# 2                            1            457700.00
# 3                         4578              1507.32
# 4                        73583               471.16
# 5                       420278               106.95
# 6                       869755                42.79
# 7                      1241907                 0.83
# 8                      1252209               -26.91
# 9                       915211               -19.24
# 10                      739136                 7.97
# 11                      798082               -26.42

# %% [markdown]
# 3.2. Consulta simplificada sem utilizar CASE e LAG() para poder realizar os passos com o Pandas

# %%
consulta_simplificada_sql = client.query('''
                            SELECT
                              countries_and_territories,
                              month,
                              SUM(daily_confirmed_cases) AS total_confirmed_cases
                            FROM
                              `bigquery-public-data.covid19_ecdc.covid_19_geographic_distribution_worldwide`
                            WHERE
                              year = 2020
                              AND countries_and_territories = 'Brazil'
                            GROUP BY
                              month,
                              countries_and_territories
                            ORDER BY
                              countries_and_territories,
                              month,
                              total_confirmed_cases
                            ''').to_dataframe()

# %%
consulta_simplificada_sql
# Out:
#    countries_and_territories  month  total_confirmed_cases
# 0                     Brazil      1                      0
# 1                     Brazil      2                      1
# 2                     Brazil      3                   4578
# 3                     Brazil      4                  73583
# 4                     Brazil      5                 420278
# 5                     Brazil      6                 869755
# 6                     Brazil      7                1241907
# 7                     Brazil      8                1252209
# 8                     Brazil      9                 915211
# 9                     Brazil     10                 739136
# 10                    Brazil     11                 798082
# 11                    Brazil     12                 587212

# %% [markdown]
# 4. Utilizando as bibliotecas Pandas para renomear o nome dos meses do DataFrame `consulta_simplificada_sql`:

# %%
consulta_simplificada_sql['month'] = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
consulta_simplificada_sql
# Out:
#    countries_and_territories month  total_confirmed_cases
# 0                     Brazil   jan                      0
# 1                     Brazil   fev                      1
# 2                     Brazil   mar                   4578
# 3                     Brazil   abr                  73583
# 4                     Brazil   mai                 420278
# 5                     Brazil   jun                 869755
# 6                     Brazil   jul                1241907
# 7                     Brazil   ago                1252209
# 8                     Brazil   set                 915211
# 9                     Brazil   out                 739136
# 10                    Brazil   nov                 798082
# 11                    Brazil   dez                 587212

# %% [markdown]
# 5. Criando a coluna `total_cases_previous_month` no DataFrame `consulta_simplificada_sql` utilizando o método `.shift()`:

# %%
consulta_simplificada_sql['total_cases_previous_month'] = consulta_simplificada_sql['total_confirmed_cases'].shift(periods=1,
                                                                                                                   axis=0)
consulta_simplificada_sql
# Out:
#    countries_and_territories month  total_confirmed_cases  \
# 0                     Brazil   jan                      0
# 1                     Brazil   fev                      1
# 2                     Brazil   mar                   4578
# 3                     Brazil   abr                  73583
# 4                     Brazil   mai                 420278
# 5                     Brazil   jun                 869755
# 6                     Brazil   jul                1241907
# 7                     Brazil   ago                1252209
# 8                     Brazil   set                 915211
# 9                     Brazil   out                 739136
# 10                    Brazil   nov                 798082
# 11                    Brazil   dez                 587212
#
#     total_cases_previous_month
# 0                         <NA>
# 1                            0
# 2                            1
# 3                         4578
# 4                        73583
# 5                       420278
# 6                       869755
# 7                      1241907
# 8                      1252209
# 9                       915211
# 10                      739136
# 11                      798082

# %% [markdown]
# 6. Criando a coluna `percentual_increase` no DataFrame `consulta_simplificada_sql`:

# %%
consulta_simplificada_sql['percent_increase'] = round(((consulta_simplificada_sql['total_confirmed_cases']
                                                      / consulta_simplificada_sql['total_cases_previous_month']) - 1) * 100,
                                                      2)
consulta_simplificada_sql
# Out:
#    countries_and_territories month  total_confirmed_cases  \
# 0                     Brazil   jan                      0
# 1                     Brazil   fev                      1
# 2                     Brazil   mar                   4578
# 3                     Brazil   abr                  73583
# 4                     Brazil   mai                 420278
# 5                     Brazil   jun                 869755
# 6                     Brazil   jul                1241907
# 7                     Brazil   ago                1252209
# 8                     Brazil   set                 915211
# 9                     Brazil   out                 739136
# 10                    Brazil   nov                 798082
# 11                    Brazil   dez                 587212
#
#     total_cases_previous_month  percent_increase
# 0                         <NA>              <NA>
# 1                            0               inf
# 2                            1          457700.0
# 3                         4578           1507.32
# 4                        73583            471.16
# 5                       420278            106.95
# 6                       869755             42.79
# 7                      1241907              0.83
# 8                      1252209            -26.91
# 9                       915211            -19.24
# 10                      739136              7.97
# 11                      798082            -26.42

# %% [markdown]
# 7. Extra:
#   * Formatação condicional;
#   * Formatação da representação decimal.

# %%
consulta_simplificada_sql.style.background_gradient(axis=0,
                                                    gmap=consulta_simplificada_sql['total_confirmed_cases'],
                                                    cmap='coolwarm'
                                                    ) \
                                .format(decimal=',', precision=2)
# Out:
# <style type="text/css">
# #T_002bc_row0_col0, #T_002bc_row0_col1, #T_002bc_row0_col2, #T_002bc_row0_col3, #T_002bc_row0_col4, #T_002bc_row1_col0, #T_002bc_row1_col1, #T_002bc_row1_col2, #T_002bc_row1_col3, #T_002bc_row1_col4, #T_002bc_row2_col0, #T_002bc_row2_col1, #T_002bc_row2_col2, #T_002bc_row2_col3, #T_002bc_row2_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_002bc_row3_col0, #T_002bc_row3_col1, #T_002bc_row3_col2, #T_002bc_row3_col3, #T_002bc_row3_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_002bc_row4_col0, #T_002bc_row4_col1, #T_002bc_row4_col2, #T_002bc_row4_col3, #T_002bc_row4_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_002bc_row5_col0, #T_002bc_row5_col1, #T_002bc_row5_col2, #T_002bc_row5_col3, #T_002bc_row5_col4 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_002bc_row6_col0, #T_002bc_row6_col1, #T_002bc_row6_col2, #T_002bc_row6_col3, #T_002bc_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_002bc_row7_col0, #T_002bc_row7_col1, #T_002bc_row7_col2, #T_002bc_row7_col3, #T_002bc_row7_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_002bc_row8_col0, #T_002bc_row8_col1, #T_002bc_row8_col2, #T_002bc_row8_col3, #T_002bc_row8_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_002bc_row9_col0, #T_002bc_row9_col1, #T_002bc_row9_col2, #T_002bc_row9_col3, #T_002bc_row9_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_002bc_row10_col0, #T_002bc_row10_col1, #T_002bc_row10_col2, #T_002bc_row10_col3, #T_002bc_row10_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_002bc_row11_col0, #T_002bc_row11_col1, #T_002bc_row11_col2, #T_002bc_row11_col3, #T_002bc_row11_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_002bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_002bc_level0_col0" class="col_heading level0 col0" >countries_and_territories</th>
#       <th id="T_002bc_level0_col1" class="col_heading level0 col1" >month</th>
#       <th id="T_002bc_level0_col2" class="col_heading level0 col2" >total_confirmed_cases</th>
#       <th id="T_002bc_level0_col3" class="col_heading level0 col3" >total_cases_previous_month</th>
#       <th id="T_002bc_level0_col4" class="col_heading level0 col4" >percent_increase</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_002bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_002bc_row0_col0" class="data row0 col0" >Brazil</td>
#       <td id="T_002bc_row0_col1" class="data row0 col1" >jan</td>
#       <td id="T_002bc_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_002bc_row0_col3" class="data row0 col3" ><NA></td>
#       <td id="T_002bc_row0_col4" class="data row0 col4" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_002bc_row1_col0" class="data row1 col0" >Brazil</td>
#       <td id="T_002bc_row1_col1" class="data row1 col1" >fev</td>
#       <td id="T_002bc_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_002bc_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_002bc_row1_col4" class="data row1 col4" >inf</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_002bc_row2_col0" class="data row2 col0" >Brazil</td>
#       <td id="T_002bc_row2_col1" class="data row2 col1" >mar</td>
#       <td id="T_002bc_row2_col2" class="data row2 col2" >4578</td>
#       <td id="T_002bc_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_002bc_row2_col4" class="data row2 col4" >457700,00</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_002bc_row3_col0" class="data row3 col0" >Brazil</td>
#       <td id="T_002bc_row3_col1" class="data row3 col1" >abr</td>
#       <td id="T_002bc_row3_col2" class="data row3 col2" >73583</td>
#       <td id="T_002bc_row3_col3" class="data row3 col3" >4578</td>
#       <td id="T_002bc_row3_col4" class="data row3 col4" >1507,32</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_002bc_row4_col0" class="data row4 col0" >Brazil</td>
#       <td id="T_002bc_row4_col1" class="data row4 col1" >mai</td>
#       <td id="T_002bc_row4_col2" class="data row4 col2" >420278</td>
#       <td id="T_002bc_row4_col3" class="data row4 col3" >73583</td>
#       <td id="T_002bc_row4_col4" class="data row4 col4" >471,16</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_002bc_row5_col0" class="data row5 col0" >Brazil</td>
#       <td id="T_002bc_row5_col1" class="data row5 col1" >jun</td>
#       <td id="T_002bc_row5_col2" class="data row5 col2" >869755</td>
#       <td id="T_002bc_row5_col3" class="data row5 col3" >420278</td>
#       <td id="T_002bc_row5_col4" class="data row5 col4" >106,95</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_002bc_row6_col0" class="data row6 col0" >Brazil</td>
#       <td id="T_002bc_row6_col1" class="data row6 col1" >jul</td>
#       <td id="T_002bc_row6_col2" class="data row6 col2" >1241907</td>
#       <td id="T_002bc_row6_col3" class="data row6 col3" >869755</td>
#       <td id="T_002bc_row6_col4" class="data row6 col4" >42,79</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_002bc_row7_col0" class="data row7 col0" >Brazil</td>
#       <td id="T_002bc_row7_col1" class="data row7 col1" >ago</td>
#       <td id="T_002bc_row7_col2" class="data row7 col2" >1252209</td>
#       <td id="T_002bc_row7_col3" class="data row7 col3" >1241907</td>
#       <td id="T_002bc_row7_col4" class="data row7 col4" >0,83</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_002bc_row8_col0" class="data row8 col0" >Brazil</td>
#       <td id="T_002bc_row8_col1" class="data row8 col1" >set</td>
#       <td id="T_002bc_row8_col2" class="data row8 col2" >915211</td>
#       <td id="T_002bc_row8_col3" class="data row8 col3" >1252209</td>
#       <td id="T_002bc_row8_col4" class="data row8 col4" >-26,91</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_002bc_row9_col0" class="data row9 col0" >Brazil</td>
#       <td id="T_002bc_row9_col1" class="data row9 col1" >out</td>
#       <td id="T_002bc_row9_col2" class="data row9 col2" >739136</td>
#       <td id="T_002bc_row9_col3" class="data row9 col3" >915211</td>
#       <td id="T_002bc_row9_col4" class="data row9 col4" >-19,24</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_002bc_row10_col0" class="data row10 col0" >Brazil</td>
#       <td id="T_002bc_row10_col1" class="data row10 col1" >nov</td>
#       <td id="T_002bc_row10_col2" class="data row10 col2" >798082</td>
#       <td id="T_002bc_row10_col3" class="data row10 col3" >739136</td>
#       <td id="T_002bc_row10_col4" class="data row10 col4" >7,97</td>
#     </tr>
#     <tr>
#       <th id="T_002bc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_002bc_row11_col0" class="data row11 col0" >Brazil</td>
#       <td id="T_002bc_row11_col1" class="data row11 col1" >dez</td>
#       <td id="T_002bc_row11_col2" class="data row11 col2" >587212</td>
#       <td id="T_002bc_row11_col3" class="data row11 col3" >798082</td>
#       <td id="T_002bc_row11_col4" class="data row11 col4" >-26,42</td>
#     </tr>
#   </tbody>
# </table>
